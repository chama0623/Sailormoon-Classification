# %% [markdown]
# ## data読み込み

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import os
import random
import seaborn as sns

random_state = 623

# %%
def load_file(files,Soldiers):
    """ファイルを読み込んでnumpy.arrayに変換する関数
    
    Args:
    files : 読み込むファイルのリスト
    Soldiers : セーラー戦士のリスト
    
    Returns:
    np.array(file_list) : 読み込んだ画像のnumpy.array
    y : 正解ラベル
    """
    file_list = []
    y=[]
    for file in files:
        # 正解ラベルをリストに代入
        for i,soldier in enumerate(Soldiers):
            if soldier in file:
                y.append(i)
                
        # load img
        f = cv2.imread(file)
        f = cv2.resize(f, dsize=(128, 128))
        f = cv2.cvtColor(f, cv2.COLOR_BGR2RGB)
        
        file_list.append(f)
    return np.array(file_list),y

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

Soldiers = ["Sailorjupiter","Sailormars","Sailormercury","Sailormoon","Sailorneptune",
            "Sailorpluto","Sailorsaturn","Sailortibimoon","Sailoruranus","Sailorvenus"]

train_path = "./train/"
test_path = "./test/"
# load data
train,y_train = load_file(glob.glob(train_path+"/*"),Soldiers)
test,y_test = load_file(glob.glob(test_path+"/*"),Soldiers)

train = train.reshape((train.shape[0], 128, 128, 3)) / 255
x_test = test.reshape((test.shape[0], 128, 128, 3)) / 255
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train, x_valid, y_train, y_valid = train_test_split(
    train, y_train,test_size=0.2,random_state=random_state)

# %%
# train,valid,testのshapeを確認
print(x_train.shape)
print(y_train.shape)
print(x_valid.shape)
print(y_valid.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (640, 128, 128, 3)
# (640, 10)
# (160, 128, 128, 3)
# (160, 10)
# (200, 128, 128, 3)
# (200, 10)

# %% [markdown]
# ## 転移学習モデルを生成

# %%
import keras
import tensorflow as tf
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D,Input

# base model(Xception)を読み込み
# include_top : 出力層側の3つのDenseを含むかどうか
base_model =  tf.keras.applications.xception.Xception(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

# base modelに出力層を追加
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024,activation="relu")(x)
prediction=Dense(10,activation='softmax')(x)
model=Model(inputs=base_model.input,outputs=prediction)
    
model.compile(
    loss=keras.losses.categorical_crossentropy,
    optimizer="adam",
    metrics=["accuracy"]
)

# %% [markdown]
# ## 学習

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

train_datagen=ImageDataGenerator(
    width_shift_range=0.4, # 左にシフトする割合
    height_shift_range=0.4, # 垂直方向にシフトする割合
    rotation_range=30, # ランダムに30度の範囲で回転
    shear_range=0.2, # 反時計回りの回転
    zoom_range=0.2, # 拡大
    horizontal_flip=True) # 水平方向に反転

validation_datagen=ImageDataGenerator()

train_datagen.fit(x_train)
validation_datagen.fit(x_valid)

train_generator=train_datagen.flow(
    x_train,y_train,
    batch_size=70,
    shuffle=True
)

validation_generator=validation_datagen.flow(
    x_valid,y_valid,
    batch_size=70,
    shuffle=True
)

early_stopping = EarlyStopping(patience=70, verbose=1)

hist=model.fit_generator(train_generator,
                         epochs=300,
                         verbose=1,
                         validation_data=validation_generator,
                         callbacks=[early_stopping])
# Out:
# C:\Users\yudai\anaconda3\envs\py38-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/300
# 10/10 [==============================] - 12s 576ms/step - loss: 2.3452 - accuracy: 0.1152 - val_loss: 2.3200 - val_accuracy: 0.1063
# Epoch 2/300
# 10/10 [==============================] - 4s 353ms/step - loss: 2.3026 - accuracy: 0.0911 - val_loss: 2.3105 - val_accuracy: 0.0812
# Epoch 3/300
# 10/10 [==============================] - 4s 352ms/step - loss: 2.3014 - accuracy: 0.1150 - val_loss: 2.3112 - val_accuracy: 0.0812
# Epoch 4/300
# 10/10 [==============================] - 4s 339ms/step - loss: 2.3014 - accuracy: 0.1228 - val_loss: 2.3139 - val_accuracy: 0.0812
# Epoch 5/300
# 10/10 [==============================] - 4s 336ms/step - loss: 2.3004 - accuracy: 0.1234 - val_loss: 2.3200 - val_accuracy: 0.0938
# Epoch 6/300
# 10/10 [==============================] - 4s 353ms/step - loss: 2.2991 - accuracy: 0.0968 - val_loss: 2.3437 - val_accuracy: 0.0688
# Epoch 7/300
# 10/10 [==============================] - 4s 357ms/step - loss: 2.3002 - accuracy: 0.1318 - val_loss: 2.4598 - val_accuracy: 0.0688
# Epoch 8/300
# 10/10 [==============================] - 3s 357ms/step - loss: 2.2979 - accuracy: 0.1196 - val_loss: 2.3870 - val_accuracy: 0.0625
# Epoch 9/300
# 10/10 [==============================] - 4s 337ms/step - loss: 2.2871 - accuracy: 0.1177 - val_loss: 2.3342 - val_accuracy: 0.0625
# Epoch 10/300
# 10/10 [==============================] - 4s 336ms/step - loss: 2.2992 - accuracy: 0.1109 - val_loss: 2.4218 - val_accuracy: 0.0750
# Epoch 11/300
# 10/10 [==============================] - 4s 336ms/step - loss: 2.2897 - accuracy: 0.0986 - val_loss: 2.6024 - val_accuracy: 0.0625
# Epoch 12/300
# 10/10 [==============================] - 3s 329ms/step - loss: 2.2727 - accuracy: 0.1007 - val_loss: 2.6111 - val_accuracy: 0.0500
# Epoch 13/300
# 10/10 [==============================] - 4s 344ms/step - loss: 2.2383 - accuracy: 0.1269 - val_loss: 5.8181 - val_accuracy: 0.0625
# Epoch 14/300
# 10/10 [==============================] - 3s 329ms/step - loss: 2.1948 - accuracy: 0.1321 - val_loss: 4.0005 - val_accuracy: 0.1063
# Epoch 15/300
# 10/10 [==============================] - 3s 330ms/step - loss: 2.2174 - accuracy: 0.1822 - val_loss: 2.9734 - val_accuracy: 0.1125
# Epoch 16/300
# 10/10 [==============================] - 4s 333ms/step - loss: 2.1619 - accuracy: 0.1746 - val_loss: 19.7608 - val_accuracy: 0.1125
# Epoch 17/300
# 10/10 [==============================] - 3s 327ms/step - loss: 2.1440 - accuracy: 0.1730 - val_loss: 21.8065 - val_accuracy: 0.1000
# Epoch 18/300
# 10/10 [==============================] - 4s 336ms/step - loss: 2.0859 - accuracy: 0.1985 - val_loss: 16.0393 - val_accuracy: 0.1000
# Epoch 19/300
# 10/10 [==============================] - 3s 373ms/step - loss: 2.1194 - accuracy: 0.1855 - val_loss: 4.8459 - val_accuracy: 0.1125
# Epoch 20/300
# 10/10 [==============================] - 3s 359ms/step - loss: 2.1667 - accuracy: 0.1891 - val_loss: 4.6549 - val_accuracy: 0.1312
# Epoch 21/300
# 10/10 [==============================] - 3s 362ms/step - loss: 2.0729 - accuracy: 0.1776 - val_loss: 2.4579 - val_accuracy: 0.1500
# Epoch 22/300
# 10/10 [==============================] - 4s 334ms/step - loss: 1.9939 - accuracy: 0.2089 - val_loss: 3.2496 - val_accuracy: 0.1250
# Epoch 23/300
# 10/10 [==============================] - 4s 334ms/step - loss: 1.9928 - accuracy: 0.2523 - val_loss: 3.4142 - val_accuracy: 0.1375
# Epoch 24/300
# 10/10 [==============================] - 4s 340ms/step - loss: 1.9466 - accuracy: 0.2187 - val_loss: 2.1883 - val_accuracy: 0.1375
# Epoch 25/300
# 10/10 [==============================] - 4s 332ms/step - loss: 1.8948 - accuracy: 0.2299 - val_loss: 2.2307 - val_accuracy: 0.1125
# Epoch 26/300
# 10/10 [==============================] - 3s 327ms/step - loss: 1.8877 - accuracy: 0.2466 - val_loss: 2.3832 - val_accuracy: 0.1250
# Epoch 27/300
# 10/10 [==============================] - 3s 369ms/step - loss: 1.9130 - accuracy: 0.2900 - val_loss: 2.3244 - val_accuracy: 0.0938
# Epoch 28/300
# 10/10 [==============================] - 3s 363ms/step - loss: 1.7857 - accuracy: 0.3285 - val_loss: 2.1344 - val_accuracy: 0.1625
# Epoch 29/300
# 10/10 [==============================] - 4s 334ms/step - loss: 1.7835 - accuracy: 0.3061 - val_loss: 3.0592 - val_accuracy: 0.1750
# Epoch 30/300
# 10/10 [==============================] - 4s 333ms/step - loss: 1.7509 - accuracy: 0.3211 - val_loss: 2.6140 - val_accuracy: 0.2438
# Epoch 31/300
# 10/10 [==============================] - 4s 339ms/step - loss: 1.6250 - accuracy: 0.3843 - val_loss: 56.6509 - val_accuracy: 0.1500
# Epoch 32/300
# 10/10 [==============================] - 4s 342ms/step - loss: 1.5208 - accuracy: 0.4353 - val_loss: 22.7543 - val_accuracy: 0.2125
# Epoch 33/300
# 10/10 [==============================] - 3s 328ms/step - loss: 1.4017 - accuracy: 0.4764 - val_loss: 37.5706 - val_accuracy: 0.1437
# Epoch 34/300
# 10/10 [==============================] - 4s 334ms/step - loss: 1.3553 - accuracy: 0.5648 - val_loss: 4.9757 - val_accuracy: 0.3812
# Epoch 35/300
# 10/10 [==============================] - 4s 335ms/step - loss: 1.2781 - accuracy: 0.5807 - val_loss: 9.9025 - val_accuracy: 0.2937
# Epoch 36/300
# 10/10 [==============================] - 4s 339ms/step - loss: 1.1936 - accuracy: 0.5879 - val_loss: 3.8179 - val_accuracy: 0.3938
# Epoch 37/300
# 10/10 [==============================] - 4s 339ms/step - loss: 1.2812 - accuracy: 0.5492 - val_loss: 29.7048 - val_accuracy: 0.2313
# Epoch 38/300
# 10/10 [==============================] - 4s 346ms/step - loss: 1.1886 - accuracy: 0.5792 - val_loss: 144.7609 - val_accuracy: 0.1312
# Epoch 39/300
# 10/10 [==============================] - 4s 343ms/step - loss: 1.0116 - accuracy: 0.6213 - val_loss: 218.3302 - val_accuracy: 0.1813
# Epoch 40/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.9792 - accuracy: 0.6489 - val_loss: 51.2498 - val_accuracy: 0.1187
# Epoch 41/300
# 10/10 [==============================] - 4s 347ms/step - loss: 0.8328 - accuracy: 0.7320 - val_loss: 22.7135 - val_accuracy: 0.1625
# Epoch 42/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.7630 - accuracy: 0.7539 - val_loss: 11.0321 - val_accuracy: 0.3750
# Epoch 43/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.7009 - accuracy: 0.7736 - val_loss: 7.7274 - val_accuracy: 0.3688
# Epoch 44/300
# 10/10 [==============================] - 4s 330ms/step - loss: 0.7133 - accuracy: 0.7555 - val_loss: 4.2458 - val_accuracy: 0.4500
# Epoch 45/300
# 10/10 [==============================] - 3s 374ms/step - loss: 0.7324 - accuracy: 0.7909 - val_loss: 6.3847 - val_accuracy: 0.3438
# Epoch 46/300
# 10/10 [==============================] - 4s 335ms/step - loss: 0.7459 - accuracy: 0.7609 - val_loss: 3.8787 - val_accuracy: 0.4500
# Epoch 47/300
# 10/10 [==============================] - 3s 376ms/step - loss: 0.6061 - accuracy: 0.8144 - val_loss: 1.8820 - val_accuracy: 0.6187
# Epoch 48/300
# 10/10 [==============================] - 4s 353ms/step - loss: 0.4811 - accuracy: 0.8437 - val_loss: 1.4558 - val_accuracy: 0.6313
# Epoch 49/300
# 10/10 [==============================] - 4s 346ms/step - loss: 0.5140 - accuracy: 0.8318 - val_loss: 3.0803 - val_accuracy: 0.5375
# Epoch 50/300
# 10/10 [==============================] - 3s 374ms/step - loss: 0.7985 - accuracy: 0.7739 - val_loss: 9.0601 - val_accuracy: 0.3750
# Epoch 51/300
# 10/10 [==============================] - 4s 330ms/step - loss: 0.6933 - accuracy: 0.7451 - val_loss: 2.7309 - val_accuracy: 0.5437
# Epoch 52/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.6615 - accuracy: 0.7772 - val_loss: 1.4617 - val_accuracy: 0.6812
# Epoch 53/300
# 10/10 [==============================] - 4s 345ms/step - loss: 0.5190 - accuracy: 0.8365 - val_loss: 1.3616 - val_accuracy: 0.6687
# Epoch 54/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.6412 - accuracy: 0.8017 - val_loss: 4.1683 - val_accuracy: 0.4250
# Epoch 55/300
# 10/10 [==============================] - 3s 324ms/step - loss: 0.5261 - accuracy: 0.8489 - val_loss: 1.9888 - val_accuracy: 0.6187
# Epoch 56/300
# 10/10 [==============================] - 3s 329ms/step - loss: 0.4200 - accuracy: 0.8814 - val_loss: 3.1203 - val_accuracy: 0.5000
# Epoch 57/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.4461 - accuracy: 0.8570 - val_loss: 2.5248 - val_accuracy: 0.6500
# Epoch 58/300
# 10/10 [==============================] - 4s 337ms/step - loss: 0.5157 - accuracy: 0.8392 - val_loss: 3.9616 - val_accuracy: 0.5688
# Epoch 59/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.4876 - accuracy: 0.8457 - val_loss: 2.8740 - val_accuracy: 0.6250
# Epoch 60/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.4387 - accuracy: 0.8730 - val_loss: 1.6540 - val_accuracy: 0.7563
# Epoch 61/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.3421 - accuracy: 0.8762 - val_loss: 6.4172 - val_accuracy: 0.5188
# Epoch 62/300
# 10/10 [==============================] - 4s 347ms/step - loss: 0.4862 - accuracy: 0.8397 - val_loss: 46.4308 - val_accuracy: 0.2875
# Epoch 63/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.3911 - accuracy: 0.8857 - val_loss: 21.3072 - val_accuracy: 0.2875
# Epoch 64/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.3970 - accuracy: 0.8625 - val_loss: 5.0521 - val_accuracy: 0.4313
# Epoch 65/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3503 - accuracy: 0.8850 - val_loss: 2.1460 - val_accuracy: 0.5875
# Epoch 66/300
# 10/10 [==============================] - 4s 337ms/step - loss: 0.3281 - accuracy: 0.8927 - val_loss: 2.0312 - val_accuracy: 0.6938
# Epoch 67/300
# 10/10 [==============================] - 3s 321ms/step - loss: 0.4788 - accuracy: 0.8692 - val_loss: 1.0094 - val_accuracy: 0.7750
# Epoch 68/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3893 - accuracy: 0.8644 - val_loss: 2.9583 - val_accuracy: 0.6625
# Epoch 69/300
# 10/10 [==============================] - 4s 382ms/step - loss: 0.6555 - accuracy: 0.8112 - val_loss: 2.5126 - val_accuracy: 0.6625
# Epoch 70/300
# 10/10 [==============================] - 4s 337ms/step - loss: 0.4354 - accuracy: 0.8738 - val_loss: 2.5621 - val_accuracy: 0.6375
# Epoch 71/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.4353 - accuracy: 0.8709 - val_loss: 1.7221 - val_accuracy: 0.7188
# Epoch 72/300
# 10/10 [==============================] - 3s 329ms/step - loss: 0.3455 - accuracy: 0.8989 - val_loss: 0.9256 - val_accuracy: 0.7937
# Epoch 73/300
# 10/10 [==============================] - 3s 371ms/step - loss: 0.4329 - accuracy: 0.8642 - val_loss: 1.9530 - val_accuracy: 0.6625
# Epoch 74/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.3672 - accuracy: 0.8905 - val_loss: 1.6221 - val_accuracy: 0.7188
# Epoch 75/300
# 10/10 [==============================] - 4s 337ms/step - loss: 0.2616 - accuracy: 0.9196 - val_loss: 1.7265 - val_accuracy: 0.6750
# Epoch 76/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.3450 - accuracy: 0.8901 - val_loss: 1.7855 - val_accuracy: 0.6562
# Epoch 77/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2884 - accuracy: 0.9085 - val_loss: 1.8059 - val_accuracy: 0.5625
# Epoch 78/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3723 - accuracy: 0.8889 - val_loss: 2.6368 - val_accuracy: 0.5562
# Epoch 79/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.3754 - accuracy: 0.8741 - val_loss: 2.2871 - val_accuracy: 0.6313
# Epoch 80/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2922 - accuracy: 0.9114 - val_loss: 1.4059 - val_accuracy: 0.6313
# Epoch 81/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.3562 - accuracy: 0.9014 - val_loss: 0.8504 - val_accuracy: 0.7750
# Epoch 82/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.2843 - accuracy: 0.9148 - val_loss: 1.2093 - val_accuracy: 0.7000
# Epoch 83/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.3180 - accuracy: 0.8979 - val_loss: 1.0375 - val_accuracy: 0.7500
# Epoch 84/300
# 10/10 [==============================] - 3s 327ms/step - loss: 0.2085 - accuracy: 0.9446 - val_loss: 0.9675 - val_accuracy: 0.7688
# Epoch 85/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.3071 - accuracy: 0.9059 - val_loss: 0.7751 - val_accuracy: 0.7937
# Epoch 86/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.3367 - accuracy: 0.9019 - val_loss: 1.4201 - val_accuracy: 0.7188
# Epoch 87/300
# 10/10 [==============================] - 4s 383ms/step - loss: 0.2839 - accuracy: 0.9283 - val_loss: 0.9017 - val_accuracy: 0.7812
# Epoch 88/300
# 10/10 [==============================] - 4s 353ms/step - loss: 0.2156 - accuracy: 0.9448 - val_loss: 0.7297 - val_accuracy: 0.8062
# Epoch 89/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.2026 - accuracy: 0.9312 - val_loss: 4.6798 - val_accuracy: 0.5437
# Epoch 90/300
# 10/10 [==============================] - 4s 331ms/step - loss: 0.2631 - accuracy: 0.9147 - val_loss: 2.5981 - val_accuracy: 0.6875
# Epoch 91/300
# 10/10 [==============================] - 4s 353ms/step - loss: 0.2172 - accuracy: 0.9377 - val_loss: 1.4529 - val_accuracy: 0.7125
# Epoch 92/300
# 10/10 [==============================] - 4s 358ms/step - loss: 0.2277 - accuracy: 0.9334 - val_loss: 1.1688 - val_accuracy: 0.7500
# Epoch 93/300
# 10/10 [==============================] - 4s 332ms/step - loss: 0.2774 - accuracy: 0.9044 - val_loss: 0.9461 - val_accuracy: 0.7750
# Epoch 94/300
# 10/10 [==============================] - 4s 354ms/step - loss: 0.2905 - accuracy: 0.9170 - val_loss: 1.2016 - val_accuracy: 0.6875
# Epoch 95/300
# 10/10 [==============================] - 4s 356ms/step - loss: 0.2708 - accuracy: 0.9132 - val_loss: 1.4082 - val_accuracy: 0.6062
# Epoch 96/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3380 - accuracy: 0.9088 - val_loss: 1.1474 - val_accuracy: 0.7063
# Epoch 97/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.2544 - accuracy: 0.9309 - val_loss: 1.1289 - val_accuracy: 0.7500
# Epoch 98/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.2208 - accuracy: 0.9353 - val_loss: 2.0158 - val_accuracy: 0.6938
# Epoch 99/300
# 10/10 [==============================] - 4s 350ms/step - loss: 0.2598 - accuracy: 0.9332 - val_loss: 1.6556 - val_accuracy: 0.7188
# Epoch 100/300
# 10/10 [==============================] - 4s 354ms/step - loss: 0.2958 - accuracy: 0.9212 - val_loss: 1.3545 - val_accuracy: 0.7875
# Epoch 101/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.2057 - accuracy: 0.9296 - val_loss: 0.5960 - val_accuracy: 0.8313
# Epoch 102/300
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1894 - accuracy: 0.9293 - val_loss: 0.5803 - val_accuracy: 0.8313
# Epoch 103/300
# 10/10 [==============================] - 4s 345ms/step - loss: 0.1670 - accuracy: 0.9534 - val_loss: 0.7348 - val_accuracy: 0.8000
# Epoch 104/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.1848 - accuracy: 0.9405 - val_loss: 1.1697 - val_accuracy: 0.7500
# Epoch 105/300
# 10/10 [==============================] - 4s 330ms/step - loss: 0.1983 - accuracy: 0.9319 - val_loss: 1.2983 - val_accuracy: 0.7312
# Epoch 106/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1864 - accuracy: 0.9513 - val_loss: 1.7103 - val_accuracy: 0.6375
# Epoch 107/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.2077 - accuracy: 0.9487 - val_loss: 0.7955 - val_accuracy: 0.7875
# Epoch 108/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.3336 - accuracy: 0.9137 - val_loss: 1.1058 - val_accuracy: 0.7250
# Epoch 109/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3460 - accuracy: 0.9037 - val_loss: 0.8493 - val_accuracy: 0.7937
# Epoch 110/300
# 10/10 [==============================] - 3s 329ms/step - loss: 0.2317 - accuracy: 0.9319 - val_loss: 0.7057 - val_accuracy: 0.7750
# Epoch 111/300
# 10/10 [==============================] - 3s 364ms/step - loss: 0.2539 - accuracy: 0.9341 - val_loss: 0.7458 - val_accuracy: 0.7625
# Epoch 112/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.2025 - accuracy: 0.9183 - val_loss: 0.4466 - val_accuracy: 0.8500
# Epoch 113/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.1455 - accuracy: 0.9627 - val_loss: 0.6985 - val_accuracy: 0.7812
# Epoch 114/300
# 10/10 [==============================] - 3s 366ms/step - loss: 0.3286 - accuracy: 0.9165 - val_loss: 0.8832 - val_accuracy: 0.7688
# Epoch 115/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.2860 - accuracy: 0.9132 - val_loss: 1.5694 - val_accuracy: 0.7875
# Epoch 116/300
# 10/10 [==============================] - 3s 369ms/step - loss: 0.2783 - accuracy: 0.9266 - val_loss: 0.8429 - val_accuracy: 0.7875
# Epoch 117/300
# 10/10 [==============================] - 4s 378ms/step - loss: 0.2729 - accuracy: 0.9217 - val_loss: 0.8787 - val_accuracy: 0.7750
# Epoch 118/300
# 10/10 [==============================] - 4s 346ms/step - loss: 0.1926 - accuracy: 0.9555 - val_loss: 1.5984 - val_accuracy: 0.6875
# Epoch 119/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2781 - accuracy: 0.9157 - val_loss: 1.0906 - val_accuracy: 0.7875
# Epoch 120/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.2518 - accuracy: 0.9274 - val_loss: 0.7738 - val_accuracy: 0.8250
# Epoch 121/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2495 - accuracy: 0.9271 - val_loss: 0.8228 - val_accuracy: 0.8188
# Epoch 122/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.2212 - accuracy: 0.9424 - val_loss: 1.4668 - val_accuracy: 0.7125
# Epoch 123/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2335 - accuracy: 0.9404 - val_loss: 4.4187 - val_accuracy: 0.5938
# Epoch 124/300
# 10/10 [==============================] - 4s 351ms/step - loss: 0.3256 - accuracy: 0.9124 - val_loss: 3.0910 - val_accuracy: 0.6375
# Epoch 125/300
# 10/10 [==============================] - 4s 347ms/step - loss: 0.2595 - accuracy: 0.9187 - val_loss: 4.1315 - val_accuracy: 0.6562
# Epoch 126/300
# 10/10 [==============================] - 3s 363ms/step - loss: 0.5770 - accuracy: 0.8684 - val_loss: 3.4692 - val_accuracy: 0.5000
# Epoch 127/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.3608 - accuracy: 0.8941 - val_loss: 2.6457 - val_accuracy: 0.4563
# Epoch 128/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.3304 - accuracy: 0.9054 - val_loss: 1.5880 - val_accuracy: 0.5813
# Epoch 129/300
# 10/10 [==============================] - 4s 330ms/step - loss: 0.2732 - accuracy: 0.9217 - val_loss: 1.1220 - val_accuracy: 0.6750
# Epoch 130/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.2746 - accuracy: 0.9203 - val_loss: 1.4550 - val_accuracy: 0.6875
# Epoch 131/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.2849 - accuracy: 0.9056 - val_loss: 1.8091 - val_accuracy: 0.6062
# Epoch 132/300
# 10/10 [==============================] - 4s 345ms/step - loss: 0.3231 - accuracy: 0.9093 - val_loss: 2.5050 - val_accuracy: 0.5688
# Epoch 133/300
# 10/10 [==============================] - 4s 334ms/step - loss: 0.2799 - accuracy: 0.9117 - val_loss: 1.3136 - val_accuracy: 0.6687
# Epoch 134/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2267 - accuracy: 0.9435 - val_loss: 0.6108 - val_accuracy: 0.8313
# Epoch 135/300
# 10/10 [==============================] - 3s 369ms/step - loss: 0.2038 - accuracy: 0.9279 - val_loss: 0.9512 - val_accuracy: 0.7437
# Epoch 136/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.2180 - accuracy: 0.9422 - val_loss: 1.3946 - val_accuracy: 0.7125
# Epoch 137/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.2131 - accuracy: 0.9508 - val_loss: 0.6567 - val_accuracy: 0.7812
# Epoch 138/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1791 - accuracy: 0.9576 - val_loss: 0.6562 - val_accuracy: 0.8188
# Epoch 139/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.1257 - accuracy: 0.9667 - val_loss: 0.5256 - val_accuracy: 0.8625
# Epoch 140/300
# 10/10 [==============================] - 3s 370ms/step - loss: 0.3003 - accuracy: 0.9182 - val_loss: 1.0624 - val_accuracy: 0.7375
# Epoch 141/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1475 - accuracy: 0.9588 - val_loss: 0.7558 - val_accuracy: 0.8250
# Epoch 142/300
# 10/10 [==============================] - 3s 375ms/step - loss: 0.2847 - accuracy: 0.9368 - val_loss: 0.7378 - val_accuracy: 0.8062
# Epoch 143/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1813 - accuracy: 0.9441 - val_loss: 0.6361 - val_accuracy: 0.8375
# Epoch 144/300
# 10/10 [==============================] - 4s 348ms/step - loss: 0.2102 - accuracy: 0.9367 - val_loss: 0.7010 - val_accuracy: 0.8125
# Epoch 145/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1520 - accuracy: 0.9551 - val_loss: 1.0029 - val_accuracy: 0.7563
# Epoch 146/300
# 10/10 [==============================] - 3s 321ms/step - loss: 0.1727 - accuracy: 0.9537 - val_loss: 0.5876 - val_accuracy: 0.8500
# Epoch 147/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1286 - accuracy: 0.9596 - val_loss: 0.5620 - val_accuracy: 0.8562
# Epoch 148/300
# 10/10 [==============================] - 4s 344ms/step - loss: 0.1145 - accuracy: 0.9565 - val_loss: 0.5842 - val_accuracy: 0.8375
# Epoch 149/300
# 10/10 [==============================] - 4s 355ms/step - loss: 0.2432 - accuracy: 0.9353 - val_loss: 0.5924 - val_accuracy: 0.8188
# Epoch 150/300
# 10/10 [==============================] - 4s 359ms/step - loss: 0.3360 - accuracy: 0.9273 - val_loss: 0.5733 - val_accuracy: 0.8500
# Epoch 151/300
# 10/10 [==============================] - 4s 359ms/step - loss: 0.2060 - accuracy: 0.9332 - val_loss: 0.5789 - val_accuracy: 0.8500
# Epoch 152/300
# 10/10 [==============================] - 4s 344ms/step - loss: 0.2167 - accuracy: 0.9270 - val_loss: 0.4255 - val_accuracy: 0.8813
# Epoch 153/300
# 10/10 [==============================] - 4s 362ms/step - loss: 0.1034 - accuracy: 0.9687 - val_loss: 0.4943 - val_accuracy: 0.8938
# Epoch 154/300
# 10/10 [==============================] - 3s 376ms/step - loss: 0.2999 - accuracy: 0.9335 - val_loss: 0.8025 - val_accuracy: 0.8438
# Epoch 155/300
# 10/10 [==============================] - 4s 349ms/step - loss: 0.2265 - accuracy: 0.9358 - val_loss: 0.4636 - val_accuracy: 0.8875
# Epoch 156/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1742 - accuracy: 0.9481 - val_loss: 0.5067 - val_accuracy: 0.8500
# Epoch 157/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1589 - accuracy: 0.9585 - val_loss: 0.5219 - val_accuracy: 0.8687
# Epoch 158/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1790 - accuracy: 0.9408 - val_loss: 0.8856 - val_accuracy: 0.7875
# Epoch 159/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.2406 - accuracy: 0.9247 - val_loss: 1.4818 - val_accuracy: 0.6562
# Epoch 160/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.2062 - accuracy: 0.9420 - val_loss: 0.8136 - val_accuracy: 0.8000
# Epoch 161/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.1599 - accuracy: 0.9421 - val_loss: 1.1202 - val_accuracy: 0.7125
# Epoch 162/300
# 10/10 [==============================] - 4s 345ms/step - loss: 0.2015 - accuracy: 0.9315 - val_loss: 1.1425 - val_accuracy: 0.7375
# Epoch 163/300
# 10/10 [==============================] - 4s 379ms/step - loss: 0.2105 - accuracy: 0.9399 - val_loss: 1.1496 - val_accuracy: 0.7063
# Epoch 164/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1751 - accuracy: 0.9443 - val_loss: 0.8121 - val_accuracy: 0.8125
# Epoch 165/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.1034 - accuracy: 0.9681 - val_loss: 0.6311 - val_accuracy: 0.8438
# Epoch 166/300
# 10/10 [==============================] - 4s 344ms/step - loss: 0.1190 - accuracy: 0.9636 - val_loss: 0.5772 - val_accuracy: 0.8188
# Epoch 167/300
# 10/10 [==============================] - 3s 372ms/step - loss: 0.4193 - accuracy: 0.8991 - val_loss: 1.3246 - val_accuracy: 0.6750
# Epoch 168/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.2324 - accuracy: 0.9369 - val_loss: 1.1798 - val_accuracy: 0.7312
# Epoch 169/300
# 10/10 [==============================] - 4s 344ms/step - loss: 0.1810 - accuracy: 0.9312 - val_loss: 1.3665 - val_accuracy: 0.7312
# Epoch 170/300
# 10/10 [==============================] - 3s 327ms/step - loss: 0.1373 - accuracy: 0.9562 - val_loss: 1.3804 - val_accuracy: 0.7812
# Epoch 171/300
# 10/10 [==============================] - 3s 325ms/step - loss: 0.1299 - accuracy: 0.9630 - val_loss: 1.2454 - val_accuracy: 0.7563
# Epoch 172/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1548 - accuracy: 0.9569 - val_loss: 0.6069 - val_accuracy: 0.8625
# Epoch 173/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1158 - accuracy: 0.9714 - val_loss: 0.6199 - val_accuracy: 0.8687
# Epoch 174/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.1074 - accuracy: 0.9727 - val_loss: 0.6246 - val_accuracy: 0.8813
# Epoch 175/300
# 10/10 [==============================] - 4s 344ms/step - loss: 0.1272 - accuracy: 0.9577 - val_loss: 0.8684 - val_accuracy: 0.7937
# Epoch 176/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.1256 - accuracy: 0.9666 - val_loss: 0.8142 - val_accuracy: 0.7812
# Epoch 177/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.1341 - accuracy: 0.9655 - val_loss: 0.6132 - val_accuracy: 0.8125
# Epoch 178/300
# 10/10 [==============================] - 3s 366ms/step - loss: 0.0873 - accuracy: 0.9808 - val_loss: 0.5350 - val_accuracy: 0.8813
# Epoch 179/300
# 10/10 [==============================] - 4s 335ms/step - loss: 0.1318 - accuracy: 0.9685 - val_loss: 0.6059 - val_accuracy: 0.8438
# Epoch 180/300
# 10/10 [==============================] - 3s 374ms/step - loss: 0.1833 - accuracy: 0.9485 - val_loss: 1.1455 - val_accuracy: 0.7500
# Epoch 181/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1069 - accuracy: 0.9772 - val_loss: 0.9765 - val_accuracy: 0.7625
# Epoch 182/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.1166 - accuracy: 0.9674 - val_loss: 0.6409 - val_accuracy: 0.8250
# Epoch 183/300
# 10/10 [==============================] - 3s 321ms/step - loss: 0.0744 - accuracy: 0.9809 - val_loss: 0.5558 - val_accuracy: 0.8500
# Epoch 184/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.0818 - accuracy: 0.9767 - val_loss: 1.6625 - val_accuracy: 0.7125
# Epoch 185/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.0922 - accuracy: 0.9741 - val_loss: 0.8452 - val_accuracy: 0.8000
# Epoch 186/300
# 10/10 [==============================] - 4s 344ms/step - loss: 0.1278 - accuracy: 0.9644 - val_loss: 0.7089 - val_accuracy: 0.8375
# Epoch 187/300
# 10/10 [==============================] - 4s 331ms/step - loss: 0.1479 - accuracy: 0.9627 - val_loss: 0.7496 - val_accuracy: 0.8313
# Epoch 188/300
# 10/10 [==============================] - 4s 335ms/step - loss: 0.1034 - accuracy: 0.9675 - val_loss: 0.6913 - val_accuracy: 0.8438
# Epoch 189/300
# 10/10 [==============================] - 4s 337ms/step - loss: 0.1135 - accuracy: 0.9667 - val_loss: 0.5171 - val_accuracy: 0.8687
# Epoch 190/300
# 10/10 [==============================] - 3s 372ms/step - loss: 0.0569 - accuracy: 0.9867 - val_loss: 0.6077 - val_accuracy: 0.8625
# Epoch 191/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1203 - accuracy: 0.9649 - val_loss: 0.6519 - val_accuracy: 0.8062
# Epoch 192/300
# 10/10 [==============================] - 3s 370ms/step - loss: 0.1506 - accuracy: 0.9551 - val_loss: 1.4669 - val_accuracy: 0.7312
# Epoch 193/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.2030 - accuracy: 0.9519 - val_loss: 1.3254 - val_accuracy: 0.6812
# Epoch 194/300
# 10/10 [==============================] - 4s 335ms/step - loss: 0.2797 - accuracy: 0.9170 - val_loss: 0.9418 - val_accuracy: 0.7875
# Epoch 195/300
# 10/10 [==============================] - 3s 327ms/step - loss: 0.1101 - accuracy: 0.9649 - val_loss: 1.4827 - val_accuracy: 0.7688
# Epoch 196/300
# 10/10 [==============================] - 4s 347ms/step - loss: 0.1185 - accuracy: 0.9535 - val_loss: 1.4680 - val_accuracy: 0.7750
# Epoch 197/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.0892 - accuracy: 0.9692 - val_loss: 1.6976 - val_accuracy: 0.7312
# Epoch 198/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1186 - accuracy: 0.9638 - val_loss: 2.4748 - val_accuracy: 0.6438
# Epoch 199/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1459 - accuracy: 0.9575 - val_loss: 1.6238 - val_accuracy: 0.7500
# Epoch 200/300
# 10/10 [==============================] - 4s 343ms/step - loss: 0.1425 - accuracy: 0.9611 - val_loss: 1.5069 - val_accuracy: 0.7250
# Epoch 201/300
# 10/10 [==============================] - 4s 345ms/step - loss: 0.1540 - accuracy: 0.9545 - val_loss: 1.0808 - val_accuracy: 0.7625
# Epoch 202/300
# 10/10 [==============================] - 3s 369ms/step - loss: 0.3222 - accuracy: 0.9393 - val_loss: 1.1537 - val_accuracy: 0.7750
# Epoch 203/300
# 10/10 [==============================] - 4s 349ms/step - loss: 0.1160 - accuracy: 0.9534 - val_loss: 1.1644 - val_accuracy: 0.7875
# Epoch 204/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.1081 - accuracy: 0.9709 - val_loss: 0.7963 - val_accuracy: 0.8062
# Epoch 205/300
# 10/10 [==============================] - 3s 326ms/step - loss: 0.1139 - accuracy: 0.9660 - val_loss: 0.7100 - val_accuracy: 0.8500
# Epoch 206/300
# 10/10 [==============================] - 4s 342ms/step - loss: 0.1485 - accuracy: 0.9484 - val_loss: 1.6734 - val_accuracy: 0.7500
# Epoch 207/300
# 10/10 [==============================] - 4s 349ms/step - loss: 0.1896 - accuracy: 0.9452 - val_loss: 1.3305 - val_accuracy: 0.7375
# Epoch 208/300
# 10/10 [==============================] - 4s 333ms/step - loss: 0.0909 - accuracy: 0.9772 - val_loss: 1.1139 - val_accuracy: 0.7875
# Epoch 209/300
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1630 - accuracy: 0.9580 - val_loss: 1.5048 - val_accuracy: 0.7188
# Epoch 210/300
# 10/10 [==============================] - 3s 371ms/step - loss: 0.3704 - accuracy: 0.9165 - val_loss: 1.8263 - val_accuracy: 0.7188
# Epoch 211/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.1425 - accuracy: 0.9467 - val_loss: 1.0259 - val_accuracy: 0.7625
# Epoch 212/300
# 10/10 [==============================] - 4s 338ms/step - loss: 0.0979 - accuracy: 0.9720 - val_loss: 0.8451 - val_accuracy: 0.8125
# Epoch 213/300
# 10/10 [==============================] - 4s 335ms/step - loss: 0.0782 - accuracy: 0.9795 - val_loss: 0.7134 - val_accuracy: 0.8313
# Epoch 214/300
# 10/10 [==============================] - 4s 340ms/step - loss: 0.1307 - accuracy: 0.9567 - val_loss: 0.6190 - val_accuracy: 0.8500
# Epoch 215/300
# 10/10 [==============================] - 4s 339ms/step - loss: 0.0728 - accuracy: 0.9851 - val_loss: 1.2943 - val_accuracy: 0.7125
# Epoch 216/300
# 10/10 [==============================] - 4s 336ms/step - loss: 0.1293 - accuracy: 0.9611 - val_loss: 0.6701 - val_accuracy: 0.8188
# Epoch 217/300
# 10/10 [==============================] - 3s 324ms/step - loss: 0.1074 - accuracy: 0.9698 - val_loss: 0.9511 - val_accuracy: 0.7812
# Epoch 218/300
# 10/10 [==============================] - 4s 341ms/step - loss: 0.2414 - accuracy: 0.9262 - val_loss: 0.9504 - val_accuracy: 0.7937
# Epoch 219/300
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1376 - accuracy: 0.9608 - val_loss: 0.7780 - val_accuracy: 0.8500
# Epoch 220/300
# 10/10 [==============================] - 4s 372ms/step - loss: 0.1581 - accuracy: 0.9449 - val_loss: 0.5847 - val_accuracy: 0.8625
# Epoch 221/300
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1093 - accuracy: 0.9747 - val_loss: 0.6042 - val_accuracy: 0.8625
# Epoch 222/300
# 10/10 [==============================] - 4s 357ms/step - loss: 0.0960 - accuracy: 0.9696 - val_loss: 0.6104 - val_accuracy: 0.8500
# Epoch 00222: early stopping

# %% [markdown]
# ## 正解率, 損失関数を確認

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# 損失関数の描画
plot_loss(hist)

# %%
# 正解率を描画
plot_acc(hist)

# %% [markdown]
# ## テストデータによる評価

# %%
# modelの評価
test_datagen=ImageDataGenerator()
test_datagen.fit(x_test)
test_generator=test_datagen.flow(
    x_test,y_test,
    batch_size=100,
    shuffle=False
)

scores = model.evaluate(test_generator)
prediction = model.predict(test_generator)
prediction_label = np.argmax(model.predict(test_generator),axis=1)
# Out:
# 2/2 [==============================] - 0s 96ms/step - loss: 0.8476 - accuracy: 0.8000

# %%
files=glob.glob(test_path+"/*")
file_list = []
y_label = []
for file in files:
    # 正解ラベルをリストに代入
    for i,soldier in enumerate(Soldiers):
        if soldier in file:
            y_label.append(i)
    # load img
    f = cv2.imread(file)
    f = cv2.cvtColor(f, cv2.COLOR_BGR2RGB)
    file_list.append(f)
test = np.array(file_list)

r =np.array(random.sample(range(0,200),25)).reshape(5,5)

fig = plt.figure(figsize=(15, 15))
k=1
for i in range(5):
    for j in range(5):
        plt.subplot(5,5,k)
        plt.imshow(test[r[i][j]])
        k+=1
        plt.xticks([]),plt.yticks([])
        plt.title("正解ラベル "+Soldiers[y_label[r[i][j]]]+"\n予測ラベル "+Soldiers[prediction_label[r[i][j]]])
        
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.1, top=0.95)
plt.show()
# Out:
# <ipython-input-102-b4449feba43f>:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   test = np.array(file_list)

# %%
# 混同行列
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_label, prediction_label)
sns.heatmap(cm)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report

print(classification_report(y_label, prediction_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        20
#            1       0.80      0.40      0.53        20
#            2       0.94      0.80      0.86        20
#            3       0.85      0.85      0.85        20
#            4       0.73      0.95      0.83        20
#            5       0.76      0.95      0.84        20
#            6       0.67      0.90      0.77        20
#            7       1.00      0.80      0.89        20
#            8       0.92      0.55      0.69        20
#            9       0.75      0.90      0.82        20
#
#     accuracy                           0.80       200
#    macro avg       0.82      0.80      0.79       200
# weighted avg       0.82      0.80      0.79       200
